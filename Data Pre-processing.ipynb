# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Anushka\OneDrive\Desktop\LLM Project\combined_library_data.csv")
data
# Out:
#                CallNo   Barcode  \
# 0             711 BET   8002128
# 1             711 BIR   8002219
# 2             711 CAP   8001742
# 3             711 DAU   8001796
# 4             711 GUA   8001790
# ...               ...       ...
# 244255  919.92304 CHA  04009761
# 244256  919.92304 ZUB  03007764
# 244257     919.94 FOD  05036395
# 244258    919.969 FRO  05036396
# 244259    919.994 ROG  05030108
#
#                                                     Title             Author  \
# 0               Re-Living the City: UABB 2015 Catalogue /                NaN
# 1                                          Paranoazinho :  Birmann, Ricardo.
# 2       City sense : shaping our environment with real...                NaN
# 3                                     The new civic art :     Duany, Andres.
# 4       Self sufficient city : envisioning the habitat...                NaN
# ...                                                   ...                ...
# ...

# %%
data.columns
# Out:
# Index(['CallNo', 'Barcode', 'Title', 'Author', 'Publisher Code', 'Year',
#        'ISBN', 'Edition', 'Pages', 'Library', 'Subject'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244260 entries, 0 to 244259
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   CallNo          244260 non-null  object
#  1   Barcode         244206 non-null  object
#  2   Title           244259 non-null  object
#  3   Author          227331 non-null  object
#  4   Publisher Code  234144 non-null  object
#  5   Year            200135 non-null  object
#  6   ISBN            192006 non-null  object
#  7   Edition         38887 non-null   object
#  8   Pages           238339 non-null  object
#  9   Library         244260 non-null  object
#  10  Subject         244260 non-null  object
# dtypes: object(11)
# memory usage: 20.5+ MB

# %%
data = data.drop(columns=['CallNo',"Barcode","Publisher Code","Edition"])

# %%
data.columns
# Out:
# Index(['Title', 'Author', 'Year', 'ISBN', 'Pages', 'Library', 'Subject'], dtype='object')

# %%
import pandas as pd

# Assuming df is your DataFrame
# Remove all rows with missing values
df_cleaned = data.dropna()

print(df_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150813 entries, 1 to 244258
# Data columns (total 7 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Title    150813 non-null  object
#  1   Author   150813 non-null  object
#  2   Year     150813 non-null  object
#  3   ISBN     150813 non-null  object
#  4   Pages    150813 non-null  object
#  5   Library  150813 non-null  object
#  6   Subject  150813 non-null  object
# dtypes: object(7)
# memory usage: 9.2+ MB
# None

# %%
df = df_cleaned.copy()

# Drop rows with missing 'Author' values
df = df.dropna(subset=['Author'])

# Define the function to handle various author name formats
def standardize_author_name(name):
    if isinstance(name, str):
        parts = name.split(', ')
        if len(parts) == 2:
            return f'{parts[1]} {parts[0]}'
        elif '.' in name:
            return ' '.join(name.split('.'))
    return name

# Apply the function to the 'Author' column using .loc to avoid warnings
df.loc[:, 'Author'] = df['Author'].apply(standardize_author_name)

print(df)
# Out:
#                                                     Title            Author  \
# 1                                          Paranoazinho :  Ricardo. Birmann
# 3                                     The new civic art :     Andres. Duany
# 6                                   The City in History :     Lewis Mumford
# 7                                   The City in History :     Lewis Mumford
# 8                                         Town Planning /      S C Rangwala
# ...                                                   ...               ...
# 244254                                          Voyager :  Stephen J., Pyne
# 244255                               A passion for Mars :   Andrew, Chaikin
# 244256                                The Case for Mars :    Robert. Zubrin
# 244257  Australia : The Guide for All Budgets Where to...      Fodor`s 2003
# 244258                                           Hawaii :   Jeanette Foster
#
# ...

# %%
file_path = 'cleaned_data.csv'

# Save the DataFrame to a CSV file
df_cleaned.to_csv(file_path, index=False)  # index=False to avoid writing row numbers

print(f"DataFrame has been saved to {file_path}")
# Out:
# DataFrame has been saved to cleaned_data.csv
